# %% [markdown]
# <a href="https://colab.research.google.com/github/chetankhairnar05/Colab/blob/main/class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LAB ASSIGNMENT1 Chetan Khairnar 0801CS231039

# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/car data - car data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail(10)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 291     brio  2015           5.40           6.10       31427    Petrol
# 292     jazz  2016           6.40           8.40       12000    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 294    amaze  2014           3.75           6.80       33019    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 291      Dealer       Manual      0
# 292      Dealer       Manual      0
# 293      Dealer       Manual      0
# 294      Dealer       Manual      0
# ...

# %%
df.shape
# Out:
# (301, 9)

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  293 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    294 non-null    object
#  7   Transmission   300 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     293.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.617167   36947.205980    0.043189
# std       2.891554       5.082812       8.723412   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       5.980000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.describe(include='all')
# Out:
#        Car_Name         Year  Selling_Price  Present_Price     Kms_Driven  \
# count       301   301.000000     301.000000     293.000000     301.000000
# unique       98          NaN            NaN            NaN            NaN
# top        city          NaN            NaN            NaN            NaN
# freq         26          NaN            NaN            NaN            NaN
# mean        NaN  2013.627907       4.661296       7.617167   36947.205980
# std         NaN     2.891554       5.082812       8.723412   38886.883882
# min         NaN  2003.000000       0.100000       0.320000     500.000000
# 25%         NaN  2012.000000       0.900000       1.200000   15000.000000
# 50%         NaN  2014.000000       3.600000       5.980000   32000.000000
# 75%         NaN  2016.000000       6.000000       9.900000   48767.000000
# max         NaN  2018.000000      35.000000      92.600000  500000.000000
#
#        Fuel_Type Seller_Type Transmission       Owner
# ...

# %%
#show all categories of all columns

print(f'Car_Name : {df['Car_Name'].unique()}')
# Out:
# Car_Name : ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
#  'Honda CB Hornet 160R' 'Yamaha FZ S V 2.0' 'Yamaha FZ 16'
#  'TVS Apache RTR 160' 'Bajaj Pulsar 150' 'Honda CBR 150' 'Hero Extreme'
#  'Bajaj Avenger 220 dtsi' 'Bajaj Avenger 150 street' 'Yamaha FZ  v 2.0'
#  'Bajaj Pulsar  NS 200' 'Bajaj Pulsar 220 F' 'TVS Apache RTR 180'
#  'Hero Passion X pro' 'Bajaj Pulsar NS 200' 'Yamaha Fazer'
#  'Honda Activa 4G' 'TVS Sport' 'Honda Dream Yuga'
# ...

# %%
#show all categories of all columns

print(f'Year : {df['Year'].unique()}')
# Out:
# Year : [2014 2013 2017 2011 2018 2015 2016 2009 2010 2012 2003 2008 2006 2005
#  2004 2007]

# %%
#show all categories of all columns

print(f'Fuel_Type : {df['Fuel_Type'].unique()}')
# Out:
# Fuel_Type : ['Petrol' 'Diesel' 'CNG']

# %%
print(f'Seller_Type : {df['Seller_Type'].unique()}')
# Out:
# Seller_Type : ['Dealer' 'Individual' nan]

# %%
print(f'Transmission : {df['Transmission'].unique()}')
# Out:
# Transmission : ['Manual' nan 'Automatic']

# %%
print(f'Owner : {df['Owner'].unique()}')
# Out:
# Owner : [0 1 3]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['Selling_Price'],bins=20)
plt.show()

# %%
plt.hist(df["Selling_Price"],bins=20)
# Out:
# (array([105.,  45.,  56.,  35.,  23.,  11.,   7.,   2.,   4.,   2.,   2.,
#           3.,   0.,   4.,   0.,   0.,   0.,   0.,   1.,   1.]),
#  array([ 0.1  ,  1.845,  3.59 ,  5.335,  7.08 ,  8.825, 10.57 , 12.315,
#         14.06 , 15.805, 17.55 , 19.295, 21.04 , 22.785, 24.53 , 26.275,
#         28.02 , 29.765, 31.51 , 33.255, 35.   ]),
#  <BarContainer object of 20 artists>)

# %%
# plot kde plot
sns.kdeplot(df['Selling_Price'])
plt.show()

# %%
fig,ax = plt.subplots(1,1)
ax.hist(df['Present_Price'],bins=[0,5,10,15,20,25])
ax.set_title("histogram of present price")
ax.set_xticks([0,5,10,15,20,25])
ax.set_xlabel("present price")
ax.set_ylabel("no. of cars")
plt.show()

# %%
fig,ax = plt.subplots(1,1)
ax.hist(df['Selling_Price'],bins=[0,5,10,15,20,25])
ax.set_title("histogram of present price")
ax.set_xticks([0,5,10,15,20,25])
ax.set_xlabel("present price")
ax.set_ylabel("no. of cars")
plt.show()

# %%
fig,ax = plt.subplots(1,1)
ax.hist(df['Kms_Driven'])
ax.set_title("histogram of present price")
# ax.set_xticks([0,5,10,15,20,25])
ax.set_xlabel("present price")
ax.set_ylabel("no. of cars")
plt.show()

# %%
fig,ax = plt.subplots(1,1)
ax.hist(df['Owner'])
ax.set_title("histogram of present price")
# ax.set_xticks([0,5,10,15,20,25])
ax.set_xlabel("present price")
ax.set_ylabel("no. of cars")
plt.show()

# %%
for col in df.select_dtypes(include =['int64','float64']).columns:
  plt.figure(figsize=(6,4))
  sns.histplot(x=df[col],bins = 20)
  plt.title(f"histogram of {col}")
  plt.show()

# %%
plt.scatter(df['Kms_Driven'],df['Selling_Price'])
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.countplot( df['Seller_Type'])

plt.title('Frequency of Customers by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Count')
plt.show()

# %%
for col in df.select_dtypes(include =['int64','float64']).columns:
  plt.figure(figsize=(6,4))
  plt.scatter(df[col],df['Selling_Price'])
  plt.title(f"scatter plot of {col} vs selling price")
  plt.xlabel(f'{col}')
  plt.ylabel('selling price')
  plt.show()

# %%
sns.lineplot(x='Year',y='Selling_Price',data=df)
plt.show()

# %%
df.Fuel_Type.value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
plt.pie(df.Fuel_Type.value_counts().values,labels=df.Fuel_Type.value_counts().index,shadow=True,autopct='%1.2f%%')
plt.legend()

# %%
plt.pie(df.Seller_Type.value_counts().values,labels=df.Seller_Type.value_counts().index,shadow=True,autopct='%1.2f%%')
plt.legend()

# %%
plt.pie(df.Transmission.value_counts().values,labels=df.Transmission.value_counts().index,shadow=True,autopct='%1.2f%%')
plt.legend()
